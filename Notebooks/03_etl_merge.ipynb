# %%
import os
import pandas as pd
import re
from rapidfuzz import process, fuzz

# Function to normalize text
def normalize_text(text):
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Remove special characters
        text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
        text = re.sub(r'\b(feat|ft|featuring|remix|version)\b', '', text)  # Remove problematic terms
    return text

# Load the CSV files
spotify_csv_path = r'D:\QuintoSemestre\ETL\Grammy_Analysis\data\spotify_updated.csv'
grammys_csv_path = r'D:\QuintoSemestre\ETL\Grammy_Analysis\data\grammys_updated_with_id.csv'  # Using the file with spotify_id

spotify_merge = pd.read_csv(spotify_csv_path)
grammy_merge = pd.read_csv(grammys_csv_path)

# Normalize the artist, song, and album names in both datasets
grammy_merge['artist_clean'] = grammy_merge['artist'].apply(normalize_text)
grammy_merge['nominee_clean'] = grammy_merge['nominee'].apply(normalize_text)
spotify_merge['artists_clean'] = spotify_merge['artists'].apply(normalize_text)
spotify_merge['track_name_clean'] = spotify_merge['track_name'].apply(normalize_text)
spotify_merge['album_name_clean'] = spotify_merge['album_name'].apply(normalize_text)

# Explode so that each artist in a list has its own row
spotify_merge = spotify_merge.explode('artists_clean')

# Direct merge based on 'spotify_id' and 'track_id'
merged_df = pd.merge(grammy_merge, spotify_merge, left_on='spotify_id', right_on='track_id', how='left')

# Find rows without a match in the merge based on spotify_id
no_match_df = merged_df[merged_df['track_id'].isnull()]

# If there are rows with no match, perform fuzzy matching
song_threshold = 70  # Threshold
artist_threshold = 70
album_threshold = 60

matches = []
for i, row in no_match_df.iterrows():
    song_match = process.extractOne(row['nominee_clean'], spotify_merge['track_name_clean'], scorer=fuzz.ratio)
    
    # Look for a match with track_name
    if song_match and song_match[1] >= song_threshold:
        matched_rows = spotify_merge[spotify_merge['track_name_clean'] == song_match[0]]
        artist_matches = []
        
        for _, matched_row in matched_rows.iterrows():
            artist_match = process.extractOne(row['artist_clean'], [matched_row['artists_clean']], scorer=fuzz.ratio)
            if artist_match and artist_match[1] >= artist_threshold:
                artist_matches.append(matched_row)  # Only add the full row
            
        if artist_matches:
            matches.extend(artist_matches)
        else:
            matches.append(row)
    else:
        # Look for a match with album_name if no match with track_name
        album_match = process.extractOne(row['nominee_clean'], spotify_merge['album_name_clean'], scorer=fuzz.ratio)
        if album_match and album_match[1] >= album_threshold:
            matched_rows = spotify_merge[spotify_merge['album_name_clean'] == album_match[0]]
            artist_matches = []
            
            for _, matched_row in matched_rows.iterrows():
                artist_match = process.extractOne(row['artist_clean'], [matched_row['artists_clean']], scorer=fuzz.ratio)
                if artist_match and artist_match[1] >= artist_threshold:
                    artist_matches.append(matched_row)  # Only add the full row
            
            if artist_matches:
                matches.extend(artist_matches)
            else:
                matches.append(row)
        else:
            matches.append(row)
    
    # Show progress every 100 rows
    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1} rows out of {len(no_match_df)}")

# Create a DataFrame with the matches
fuzzy_matched_df = pd.DataFrame(matches)

# Concatenate the results of the direct merge and the fuzzy matches
final_merged_df = pd.concat([merged_df.reset_index(drop=True), fuzzy_matched_df.reset_index(drop=True)], ignore_index=True)

# Drop auxiliary columns except 'spotify_id'
final_merged_df = final_merged_df.drop(columns=['artist_clean', 'nominee_clean', 'artists_clean', 'track_name_clean', 'album_name_clean'], errors='ignore')

# Ensure that the 'spotify_id' column remains
if 'spotify_id' not in final_merged_df.columns:
    print("The 'spotify_id' column is not present in the final DataFrame.")
else:
    print("The 'spotify_id' column is present in the final DataFrame.")

# Remove duplicates
final_merged_df = final_merged_df.drop_duplicates(subset=['nominee', 'artist', 'category'])

# Check the number of rows after the merge
merged_count = final_merged_df.shape[0]
print(f"Number of rows after the merge: {merged_count}")

# Optional: Verify the first rows of the cleaned DataFrame
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
final_merged_df.head(20)

# Optional: Save the resulting DataFrame to a CSV file
output_path = r'D:\QuintoSemestre\ETL\Grammy_Analysis\data\final_merged_spotify_grammys.csv'
final_merged_df.to_csv(output_path, index=False)
print(f"Merge completed and file saved as '{output_path}'.")

# %%
import requests
import base64
import os

# Set your Spotify client credentials
client_id = os.getenv('SPOTIFY_CLIENT_ID')  # Add your credentials
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')  # Add your credentials

def get_spotify_access_token(client_id, client_secret):
    url = "https://accounts.spotify.com/api/token"

    # Encode credentials in base64
    auth_string = f"{client_id}:{client_secret}"
    b64_auth_string = base64.b64encode(auth_string.encode()).decode()

    headers = {
        "Authorization": f"Basic {b64_auth_string}"
    }
    data = {
        "grant_type": "client_credentials"
    }

    # Make the POST request to get the access token
    response = requests.post(url, headers=headers, data=data)

    if response.status_code == 200:
        token_info = response.json()
        access_token = token_info['access_token']
        print(f"Access Token: {access_token}")
        return access_token
    else:
        print(f"Error: {response.status_code}, {response.text}")
        return None

# Get the Spotify access token
token = get_spotify_access_token(client_id, client_secret)
# Out:
# Access Token: BQAMEWA1LgPkH9YRxy7G6yQKv0FSCYhd9nrey-FioLBNu22gUiBG2yluz8ZC5TKLDelTkaZcahrY2wgGEnIyHibWBSR0u_rXe0lDYWUSS2KuHMXYiyg

# %%
import pandas as pd
import requests
import time

# Path to the CSV file
csv_path = r'D:\QuintoSemestre\ETL\Grammy_Analysis\data\final_merged_spotify_grammys.csv'

# Load the CSV file
final_merged_df = pd.read_csv(csv_path)

# Check if the required columns exist
required_columns = ['track_id', 'spotify_id']
for col in required_columns:
    if col not in final_merged_df.columns:
        raise ValueError(f"The column '{col}' is not found in the DataFrame.")

# Define a function to query the Spotify API (track information)
def get_spotify_info(spotify_id, access_token):
    url = f"https://api.spotify.com/v1/tracks/{spotify_id}"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an error if the response is not 200
        return response.json()  # Return track data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching track information for {spotify_id}: {e}")
        return None  # Error handling

# Define a function to query the Spotify API (audio features)
def get_audio_features(spotify_id, access_token, retries=5, backoff_factor=2):
    url = f"https://api.spotify.com/v1/audio-features/{spotify_id}"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    
    for i in range(retries):
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()  # Raise an error if the response is not 200
            return response.json()  # Return audio features
        except requests.exceptions.HTTPError as http_err:
            if response.status_code == 429:  # If 'Too Many Requests' status is received
                retry_after = int(response.headers.get("Retry-After", backoff_factor))
                wait_time = retry_after * (backoff_factor ** i)
                print(f"Too many requests. Waiting {wait_time} seconds before retrying...")
                time.sleep(wait_time)
            else:
                print(f"Error fetching audio features for {spotify_id}: {http_err}")
                return None  # Error handling
        except requests.exceptions.RequestException as e:
            print(f"Error fetching audio features for {spotify_id}: {e}")
            return None
    return None  # If after multiple attempts, the response can't be obtained

# Access token (you need to update this with your valid token)
ACCESS_TOKEN = 'BQAMEWA1LgPkH9YRxy7G6yQKv0FSCYhd9nrey-FioLBNu22gUiBG2yluz8ZC5TKLDelTkaZcahrY2wgGEnIyHibWBSR0u_rXe0lDYWUSS2KuHMXYiyg'

# Limit API requests (Spotify recommends a max of 50-100 per second, depending on the API)
REQUEST_DELAY = 0.5  # Half-second delay between each request

# Iterate over the DataFrame to fill NaNs
for index, row in final_merged_df[final_merged_df['track_id'].isnull()].iterrows():
    spotify_id = row['spotify_id']  # Ensure this column exists
    
    if pd.notna(spotify_id):  # Check if spotify_id is not NaN
        try:
            # Fetch track information from Spotify
            track_info = get_spotify_info(spotify_id, ACCESS_TOKEN)
            
            if track_info:
                # Fill in relevant columns
                final_merged_df.loc[index, 'track_id'] = track_info.get('id')
                final_merged_df.loc[index, 'artists'] = ', '.join([artist['name'] for artist in track_info.get('artists', [])])
                final_merged_df.loc[index, 'album_name'] = track_info.get('album', {}).get('name')
                final_merged_df.loc[index, 'track_name'] = track_info.get('name')
                final_merged_df.loc[index, 'popularity'] = track_info.get('popularity')
                final_merged_df.loc[index, 'duration_ms'] = track_info.get('duration_ms')
            
                # Fetch audio features
                audio_features = get_audio_features(spotify_id, ACCESS_TOKEN)
                
                if audio_features:
                    final_merged_df.loc[index, 'danceability'] = audio_features.get('danceability')
                    final_merged_df.loc[index, 'energy'] = audio_features.get('energy')
                    final_merged_df.loc[index, 'tempo'] = audio_features.get('tempo')
                    final_merged_df.loc[index, 'track_genre'] = track_info.get('genre', None)  # If genre is available
                
            # Show progress every 100 rows
            if index % 100 == 0:
                print(f"Information filled in row {index}")
        
        except Exception as e:
            print(f"Error processing row {index}: {e}")

        # Add a delay between each request to avoid overwhelming the API
        time.sleep(REQUEST_DELAY)

# Check how many rows still have NaN after processing
remaining_nan_counts = final_merged_df.isnull().sum()
print("NaN count after processing:")
print(remaining_nan_counts)

# Optional: Verify the first rows of the cleaned DataFrame
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
print(final_merged_df.head(20))  # Ensure to print the DataFrame

# Optionally save the updated result to a new CSV file
# output_path = r'C:\Users\USUARIO\Documents\Workshop2\notebooks\Merged_Updated.csv'
# final_merged_df.to_csv(output_path, index=False)
# print(f"Updated file saved to: {output_path}")
# Out:
# Información rellenada en fila 100
# Información rellenada en fila 200
# Información rellenada en fila 300
# Error al obtener información del track 1ZwdS5xdxEREPySFridCfh: 404 Client Error: Not Found for url: https://api.spotify.com/v1/tracks/1ZwdS5xdxEREPySFridCfh
# Información rellenada en fila 400
# Información rellenada en fila 500
# Información rellenada en fila 600
# Información rellenada en fila 700
# Información rellenada en fila 800
# Información rellenada en fila 900
# Información rellenada en fila 1000
# Información rellenada en fila 1100
# Información rellenada en fila 1200
# Información rellenada en fila 1300
# Información rellenada en fila 1400
# Información rellenada en fila 1500
# Información rellenada en fila 1600
# Información rellenada en fila 1700
# Información rellenada en fila 1800
# Información rellenada en fila 1900
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 2 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 4 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 8 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 16 segundos antes de reintentar...
# Demasiadas solicitudes. Esperando 32 segundos antes de reintentar...
# Error al obtener información del track 5NHTtXGCdO7ul16xr0q93w: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5NHTtXGCdO7ul16xr0q93w
# Error al obtener información del track 7zq5lyei1uoskShdtxQO1o: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/7zq5lyei1uoskShdtxQO1o
# Error al obtener información del track 3Xt76YpwUGZIx8QWvgYegg: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3Xt76YpwUGZIx8QWvgYegg
# Error al obtener información del track 3Xt76YpwUGZIx8QWvgYegg: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3Xt76YpwUGZIx8QWvgYegg
# Error al obtener información del track 75JFxkI2RXiU7L9VXzMkle: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/75JFxkI2RXiU7L9VXzMkle
# Error al obtener información del track 6cLEzlBcKhM7J6EiMSxlLv: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6cLEzlBcKhM7J6EiMSxlLv
# Error al obtener información del track 5PCJldueshnwqQVjS16543: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5PCJldueshnwqQVjS16543
# Error al obtener información del track 39sdlCugrGBsoC4Flos0HO: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/39sdlCugrGBsoC4Flos0HO
# Error al obtener información del track 3Um9toULmYFGCpvaIPFw7l: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3Um9toULmYFGCpvaIPFw7l
# Error al obtener información del track 0awKSn8GziBuAXDeHp2Bm8: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0awKSn8GziBuAXDeHp2Bm8
# Error al obtener información del track 0ieS2bue78yadTdPiyzsaO: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0ieS2bue78yadTdPiyzsaO
# Error al obtener información del track 4C8bbFSl37YUCoVeyr3Fl3: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/4C8bbFSl37YUCoVeyr3Fl3
# Error al obtener información del track 6zMUIb4uce1CzpbjR3vMdN: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6zMUIb4uce1CzpbjR3vMdN
# Error al obtener información del track 5rwKik1i0t9Pxt4ZRHKewV: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5rwKik1i0t9Pxt4ZRHKewV
# Error al obtener información del track 04KTF78FFg8sOHC1BADqbY: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/04KTF78FFg8sOHC1BADqbY
# Error al obtener información del track 1mpSmPwWONa4LFdvpzcM7S: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1mpSmPwWONa4LFdvpzcM7S
# Error al obtener información del track 0ARK753YaiJbpLUk7z5yIM: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0ARK753YaiJbpLUk7z5yIM
# Error al obtener información del track 3Prk96Esj2yy7RHfseIWOG: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3Prk96Esj2yy7RHfseIWOG
# Error al obtener información del track 0478mQXa11keCCdpWKEKgU: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0478mQXa11keCCdpWKEKgU
# Error al obtener información del track 41cm0jYZCvTcBeYZQ8lnwV: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/41cm0jYZCvTcBeYZQ8lnwV
# Error al obtener información del track 2lSUGI2s9EjbA93nahmpsL: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2lSUGI2s9EjbA93nahmpsL
# Error al obtener información del track 4aOQG9TYcZOhT3sngkMI9K: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/4aOQG9TYcZOhT3sngkMI9K
# Error al obtener información del track 2x1jP9BexWtOKudvuUHbaD: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2x1jP9BexWtOKudvuUHbaD
# Error al obtener información del track 1nvrcZ6nQaxfYa1fPQpITJ: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1nvrcZ6nQaxfYa1fPQpITJ
# Error al obtener información del track 036owkuVYakRTHo7fuZe5a: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/036owkuVYakRTHo7fuZe5a
# Error al obtener información del track 33HCAESc17DVAjqPTZ4tPa: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/33HCAESc17DVAjqPTZ4tPa
# Información rellenada en fila 2000
# Error al obtener información del track 3iPYTo54a7gimA0kdp8x13: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3iPYTo54a7gimA0kdp8x13
# Error al obtener información del track 6LfNBoBMp1pJtnm2VQm0gy: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6LfNBoBMp1pJtnm2VQm0gy
# Error al obtener información del track 5SdzS0afk0IK4TVVUCar5i: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5SdzS0afk0IK4TVVUCar5i
# Error al obtener información del track 3pD0f7hSJg2XdQ6udw5Tey: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3pD0f7hSJg2XdQ6udw5Tey
# Error al obtener información del track 1SCZdUny74IGIsMOb5OYjL: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1SCZdUny74IGIsMOb5OYjL
# Error al obtener información del track 0yXbZrzBQYi5jygezSvXAe: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0yXbZrzBQYi5jygezSvXAe
# Error al obtener información del track 2BiCH1atqXX1OXOtL0PKHS: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2BiCH1atqXX1OXOtL0PKHS
# Error al obtener información del track 0dMd4rilfd6gPbXaLpNYhu: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0dMd4rilfd6gPbXaLpNYhu
# Error al obtener información del track 69xcsFdjxsaK0ix3EpS4Qw: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/69xcsFdjxsaK0ix3EpS4Qw
# Error al obtener información del track 1EHOvHPTQeCNmsewnDuVN1: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1EHOvHPTQeCNmsewnDuVN1
# Error al obtener información del track 7DhYjNLksXZhbRQeheAums: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/7DhYjNLksXZhbRQeheAums
# Error al obtener información del track 2zLLGT8WWT1dl73TlVL9qs: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2zLLGT8WWT1dl73TlVL9qs
# Error al obtener información del track 6NCHGLtC4B8XWVvRuGmRRp: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6NCHGLtC4B8XWVvRuGmRRp
# Error al obtener información del track 3QeEd0ldRZKcHixmS9TJQp: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3QeEd0ldRZKcHixmS9TJQp
# Error al obtener información del track 0pCOrSCA7dbZj0J75hOnok: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0pCOrSCA7dbZj0J75hOnok
# Error al obtener información del track 6vJSBlhgcGFTnHn3UsHgpt: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6vJSBlhgcGFTnHn3UsHgpt
# Error al obtener información del track 13syy8gRhefDlNIBfe0ZKh: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/13syy8gRhefDlNIBfe0ZKh
# Error al obtener información del track 1rq0nbpxSLVy9Z9m755ZOu: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1rq0nbpxSLVy9Z9m755ZOu
# Error al obtener información del track 79EkGysjP2dL5GdpeQjRxT: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/79EkGysjP2dL5GdpeQjRxT
# Error al obtener información del track 6lZhqWTCznlvIwvHuKo1Vy: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6lZhqWTCznlvIwvHuKo1Vy
# Error al obtener información del track 3N2nIBN3a9J40PIij4gW5F: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3N2nIBN3a9J40PIij4gW5F
# Error al obtener información del track 2s0TZZRqvJ1OZv949BRMI4: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2s0TZZRqvJ1OZv949BRMI4
# Error al obtener información del track 375hpgjNZs384XjLa6QkEM: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/375hpgjNZs384XjLa6QkEM
# Error al obtener información del track 6QPXrc4kjOU8PNll8YTW8A: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6QPXrc4kjOU8PNll8YTW8A
# Error al obtener información del track 5peixN91cw3RcnlC5wUfNH: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5peixN91cw3RcnlC5wUfNH
# Error al obtener información del track 5spAjqC772iC2KzDvEkmSr: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5spAjqC772iC2KzDvEkmSr
# Error al obtener información del track 0nqgJtiDhEGcK7tIabHaxV: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0nqgJtiDhEGcK7tIabHaxV
# Error al obtener información del track 3pMsqOoZTtzUiZXmDVtrCD: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/
 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0Qq0QqcAgW9xIOKB0e2Wxt
# Error al obtener información del track 2PHlAHDXJX95QLHS8BBvAb: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2PHlAHDXJX95QLHS8BBvAb
# Error al obtener información del track 04wEqg7pYcqALVV2FMoZ4S: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/04wEqg7pYcqALVV2FMoZ4S
# Error al obtener información del track 0dmCB1Lq8VLLLALb9eenyA: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0dmCB1Lq8VLLLALb9eenyA
# Error al obtener información del track 3PZW66625MiyEmZaat7tce: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3PZW66625MiyEmZaat7tce
# Error al obtener información del track 4AGdVxYL7xi62fAjdvVP0h: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/4AGdVxYL7xi62fAjdvVP0h
# Error al obtener información del track 0YwNdeDFbGP6AGwsQrtzdY: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0YwNdeDFbGP6AGwsQrtzdY
# Error al obtener información del track 5zO6zyBZd6zqdFBBDZKIds: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5zO6zyBZd6zqdFBBDZKIds
# Error al obtener información del track 62X5Nc50jIaHp1l1yujjKi: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/62X5Nc50jIaHp1l1yujjKi
# Error al obtener información del track 27XPIRoygTWWl9wj8T9Am9: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/27XPIRoygTWWl9wj8T9Am9
# Error al obtener información del track 15QU0nHLuEQBETnFRj3xyN: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/15QU0nHLuEQBETnFRj3xyN
# Error al obtener información del track 2hKdd3qO7cWr2Jo0Bcs0MA: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2hKdd3qO7cWr2Jo0Bcs0MA
# Error al obtener información del track 5JZ1jTanqLWVuThmZ6XRAc: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5JZ1jTanqLWVuThmZ6XRAc
# Error al obtener información del track 6XnNSPDZQXrbxbcO0IQ3ED: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6XnNSPDZQXrbxbcO0IQ3ED
# Error al obtener información del track 22HoEdG5qUa6NWMZ7vnoXO: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/22HoEdG5qUa6NWMZ7vnoXO
# Error al obtener información del track 6YvEvzEhfUlAZ86Nc32yVr: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6YvEvzEhfUlAZ86Nc32yVr
# Error al obtener información del track 1LGqJ3nvxpVXDWpEzq4DJD: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1LGqJ3nvxpVXDWpEzq4DJD
# Error al obtener información del track 1Kx5LdJPpqRXKUUHBu9CTe: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1Kx5LdJPpqRXKUUHBu9CTe
# Error al obtener información del track 06B1Aj15InZZmiwXQ3EitH: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/06B1Aj15InZZmiwXQ3EitH
# Error al obtener información del track 0nzU5b8ekr04Nqtt5F2Ch8: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0nzU5b8ekr04Nqtt5F2Ch8
# Error al obtener información del track 1yzRbzD18HXAKcz4YYXwfd: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1yzRbzD18HXAKcz4YYXwfd
# Error al obtener información del track 05FVKhhXUv4pkgdKajx2XI: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/05FVKhhXUv4pkgdKajx2XI
# Error al obtener información del track 1inCGcskZI0yUF82Zer4Gc: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1inCGcskZI0yUF82Zer4Gc
# Error al obtener información del track 1GT8y9YtzsSbT2mgtcoSCI: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1GT8y9YtzsSbT2mgtcoSCI
# Error al obtener información del track 1inCGcskZI0yUF82Zer4Gc: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1inCGcskZI0yUF82Zer4Gc
# Error al obtener información del track 5plEQCM0djZmV2gHUBfX7A: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5plEQCM0djZmV2gHUBfX7A
# Error al obtener información del track 63kHt9dnIKiCobKqMsgahS: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/63kHt9dnIKiCobKqMsgahS
# Error al obtener información del track 2yg3mUqYLVoy5Xe4P6fVid: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2yg3mUqYLVoy5Xe4P6fVid
# Error al obtener información del track 6suv3W42jWPgNXTi87TPuC: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6suv3W42jWPgNXTi87TPuC
# Error al obtener información del track 0Z6877OqQFGXowmMhfNS9a: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0Z6877OqQFGXowmMhfNS9a
# Error al obtener información del track 24cgBBhZD1cWekUqaYuqTB: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/24cgBBhZD1cWekUqaYuqTB
# Error al obtener información del track 1aMeBqrCnPf1CzRXlKyNFs: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1aMeBqrCnPf1CzRXlKyNFs
# Error al obtener información del track 4wtKuzdcuFn42ftye2lhT5: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/4wtKuzdcuFn42ftye2lhT5
# Error al obtener información del track 08kB9HSfrcIi83rymwgjMz: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/08kB9HSfrcIi83rymwgjMz
# Error al obtener información del track 3LLMJ2mIlje0QQL5YuCOK5: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3LLMJ2mIlje0QQL5YuCOK5
# Error al obtener información del track 1VuBmEauSZywQVtqbxNqka: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1VuBmEauSZywQVtqbxNqka
# Error al obtener información del track 2C3Gjo4k42nkHMqWZSnWqM: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2C3Gjo4k42nkHMqWZSnWqM
# Error al obtener información del track 1VuBmEauSZywQVtqbxNqka: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1VuBmEauSZywQVtqbxNqka
# Error al obtener información del track 52VXOTk1EBADtaNIsXJKZW: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/52VXOTk1EBADtaNIsXJKZW
# Error al obtener información del track 6tj4Xa4fq6UVIyYHOmwJXh: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6tj4Xa4fq6UVIyYHOmwJXh
# Error al obtener información del track 0tSetyzVMV1lSylhrYGZoS: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0tSetyzVMV1lSylhrYGZoS
# Error al obtener información del track 6bnOu9rhiyckKXAy9uZfHy: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6bnOu9rhiyckKXAy9uZfHy
# Error al obtener información del track 2Xtsv7BUMrNodQWH2JPOc0: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2Xtsv7BUMrNodQWH2JPOc0
# Error al obtener información del track 1H5tvpoApNDxvxDexoaAUo: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1H5tvpoApNDxvxDexoaAUo
# Error al obtener información del track 6wk3y1cRtFxFwfszyqxqDK: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/6wk3y1cRtFxFwfszyqxqDK
# Error al obtener información del track 2C3Gjo4k42nkHMqWZSnWqM: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2C3Gjo4k42nkHMqWZSnWqM
# Error al obtener información del track 32OtZ5RAwhtsakldKwsXih: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/32OtZ5RAwhtsakldKwsXih
# Error al obtener información del track 19P4fwkPhE6yVAXApFWDoF: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/19P4fwkPhE6yVAXApFWDoF
# Error al obtener información del track 2S2od3hT7ceytw7d1pTRuE: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/2S2od3hT7ceytw7d1pTRuE
# Error al obtener información del track 1VuBmEauSZywQVtqbxNqka: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1VuBmEauSZywQVtqbxNqka
# Error al obtener información del track 3jnYlchDDAiLzfkPPy12ig: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3jnYlchDDAiLzfkPPy12ig
# Error al obtener información del track 1E2AfYuobMm18cKEoQaRob: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/1E2AfYuobMm18cKEoQaRob
# Error al obtener información del track 0eKyHwckh9vQb8ncZ2DXCs: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/0eKyHwckh9vQb8ncZ2DXCs
# Error al obtener información del track 3QDahKSqLwYJYQRbILdzS6: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/3QDahKSqLwYJYQRbILdzS6
# Error al obtener información del track 7f1Dmr246cJ9uQYdbplTbh: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/7f1Dmr246cJ9uQYdbplTbh
# Error al obtener información del track 4oPNN7syJYSjzDhRerF966: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/4oPNN7syJYSjzDhRerF966
# Error al obtener información del track 5uGsG0LfotfWDq6hql4h53: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/5uGsG0LfotfWDq6hql4h53
# Error al obtener información del track 4nMETByPKJtHhBcyBYbOTj: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/tracks/
HEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 9                                          Exit Signs
# 10                   Somebody’s Watching Me (Sped Up)
# 11                                      thank u, next
# 12                                 I Used To Know Her
# 13                                       Lukas Graham
# 14                      Cuz I Love You (Super Deluxe)
# 15                                Father of the Bride
# 16           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 17       A Star Is Born Soundtrack (Without Dialogue)
# 18                          Magna Carta... Holy Grail
# 19                                   While I'm Livin'
#
#                                        track_name  popularity explicit  \
# 0                                         bad guy        84.0    False
# 1                                         Hey, Ma        58.0      NaN
# 2                                         7 rings        84.0     True
# 3                                      Hard Place        54.0      NaN
# 4                     Talk Dirty (feat. 2 Chainz)        67.0      NaN
# 5                                   Old Town Road        77.0    False
# 6                                     Truth Hurts        69.0      NaN
# 7   Sunflower - Spider-Man: Into the Spider-Verse        80.0      NaN
# 8                           when the party's over        83.0      NaN
# 9                                             I,I         0.0      NaN
# 10        Somebody's Watching Me - Single Version        65.0      NaN
# 11                                  thank u, next        82.0     True
# 12            Could've Been (feat. Bryson Tiller)        75.0      NaN
# 13                                        7 Years        80.0      NaN
# 14                                    Truth Hurts        69.0      NaN
# 15                                   Harmony Hall        59.0      NaN
# 16                                        bad guy        84.0    False
# 17                    Always Remember Us This Way        82.0      NaN
# 18                                     Holy Grail        60.0      NaN
# 19                           Bring My Flowers Now        34.0      NaN
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.701   0.425  7.0   -10.965   1.0       0.3750        0.3280
# 1          0.325   0.286  NaN       NaN   NaN          NaN           NaN
# 2          0.778   0.317  1.0   -10.732   0.0       0.3340        0.5920
# 3          0.614   0.719  NaN       NaN   NaN          NaN           NaN
# 4          0.760   0.652  NaN       NaN   NaN          NaN           NaN
# 5          0.907   0.530  1.0    -6.112   1.0       0.1270        0.0578
# 6          0.715   0.624  NaN       NaN   NaN          NaN           NaN
# 7          0.760   0.478  NaN       NaN   NaN          NaN           NaN
# 8          0.367   0.111  NaN       NaN   NaN          NaN           NaN
# 9          0.568   0.709  NaN       NaN   NaN          NaN           NaN
# 10         0.788   0.576  NaN       NaN   NaN          NaN           NaN
# 11         0.717   0.653  1.0    -5.634   1.0       0.0658        0.2290
# 12         0.450   0.352  NaN       NaN   NaN          NaN           NaN
# 13         0.765   0.473  NaN       NaN   NaN          NaN           NaN
# 14         0.715   0.624  NaN       NaN   NaN          NaN           NaN
# 15         0.653   0.760  NaN       NaN   NaN          NaN           NaN
# 16         0.701   0.425  7.0   -10.965   1.0       0.3750        0.3280
# 17         0.549   0.502  NaN       NaN   NaN          NaN           NaN
# 18         0.676   0.534  NaN       NaN   NaN          NaN           NaN
# 19         0.557   0.198  NaN       NaN   NaN          NaN           NaN
#
#     instrumentalness  liveness  valence    tempo  time_signature track_genre  \
# 0           0.130000    0.1000    0.562  135.128             4.0     electro
# 1                NaN       NaN      NaN  144.296             NaN        None
# 2           0.000000    0.0881    0.327  140.048             4.0       dance
# 3                NaN       NaN      NaN  160.075             NaN        None
# 4                NaN       NaN      NaN  100.315             NaN        None
# 5           0.000002    0.1010    0.507  135.998             4.0     hip-hop
# 6                NaN       NaN      NaN  158.087             NaN        None
# 7                NaN       NaN      NaN   89.908             NaN        None
# 8                NaN       NaN      NaN   82.642             NaN        None
# 9                NaN       NaN      NaN  106.040             NaN        None
# 10               NaN       NaN      NaN  124.115             NaN        None
# 11          0.000000    0.1010    0.412  106.966             4.0       dance
# 12               NaN       NaN      NaN  102.679             NaN        None
# 13               NaN       NaN      NaN  119.992             NaN        None
# 14               NaN       NaN      NaN  158.087             NaN        None
# 15               NaN       NaN      NaN   98.008             NaN        None
# 16          0.130000    0.1000    0.562  135.128             4.0     electro
# 17               NaN       NaN      NaN  129.842             NaN        None
# 18               NaN       NaN      NaN  145.082             NaN        None
# 19               NaN       NaN      NaN  133.823             NaN        None
#
#     duration_sec  id  duration_ms
# 0        194.087 NaN          NaN
# 1            NaN NaN     216706.0
# 2        178.626 NaN          NaN
# 3            NaN NaN     271733.0
# 4            NaN NaN     177685.0
# 5        113.000 NaN          NaN
# 6            NaN NaN     173325.0
# 7            NaN NaN     158040.0
# 8            NaN NaN     196077.0
# 9            NaN NaN     185251.0
# 10           NaN NaN     238786.0
# 11       207.320 NaN          NaN
# 12           NaN NaN     252746.0
# 13           NaN NaN     237300.0
# 14           NaN NaN     173325.0
# 15           NaN NaN     308733.0
# 16       194.087 NaN          NaN
# 17           NaN NaN     210200.0
# 18           NaN NaN     338413.0
# 19           NaN NaN     260360.0

# %%
import pandas as pd


# Opcional: Verificar las primeras filas del DataFrame limpio
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
final_merged_df.head(5)
# Out:
#    id_x    year                              title         published_at  \
# 0   1.0  2019.0  62nd Annual GRAMMY Awards  (2019)  2020-05-19 05:10:28
# 1   2.0  2019.0  62nd Annual GRAMMY Awards  (2019)  2020-05-19 05:10:28
# 2   3.0  2019.0  62nd Annual GRAMMY Awards  (2019)  2020-05-19 05:10:28
# 3   4.0  2019.0  62nd Annual GRAMMY Awards  (2019)  2020-05-19 05:10:28
# 4   5.0  2019.0  62nd Annual GRAMMY Awards  (2019)  2020-05-19 05:10:28
#
#             updated_at            category     nominee         artist  \
# 0  2020-05-19 05:10:28  Record Of The Year     Bad Guy  Billie Eilish
# 1  2020-05-19 05:10:28  Record Of The Year     Hey, Ma       Bon Iver
# 2  2020-05-19 05:10:28  Record Of The Year     7 rings  Ariana Grande
# 3  2020-05-19 05:10:28  Record Of The Year  Hard Place         H.E.R.
# 4  2020-05-19 05:10:28  Record Of The Year        Talk         Khalid
#
#                                              workers  \
# 0  Finneas O'Connell, producer; Rob Kinelski & Fi...
# 1  BJ Burton, Brad Cook, Chris Messina & Justin V...
# 2  Charles Anderson, Tommy Brown, Michael Foster ...
# 3  Rodney “Darkchild” Jerkins, producer; Joseph H...
# 4  Disclosure & Denis Kosiak, producers; Ingmar C...
#
#                                                  img winner  \
# 0  https://www.grammy.com/sites/com/files/styles/...   True
# 1  https://www.grammy.com/sites/com/files/styles/...   True
# 2  https://www.grammy.com/sites/com/files/styles/...   True
# 3  https://www.grammy.com/sites/com/files/styles/...   True
# 4  https://www.grammy.com/sites/com/files/styles/...   True
#
#                spotify_id     id_y                track_id  \
# 0  2Fxmhks0bxGSBdJ92vM42m  30867.0  2Fxmhks0bxGSBdJ92vM42m
# 1  0RstfX9nRY1Lfuy1808MoT      NaN  0RstfX9nRY1Lfuy1808MoT
# 2  6ocbgoVGwYJhOv1GgI9NsF  19913.0  6ocbgoVGwYJhOv1GgI9NsF
# 3  4IablJ6SqVNGY4vrseyKxu      NaN  4IablJ6SqVNGY4vrseyKxu
# 4  6g6A7qNhTfUgOSH7ROOxTD      NaN  6g6A7qNhTfUgOSH7ROOxTD
#
#                   artists                                album_name  \
# 0           Billie Eilish  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 1                Bon Iver                                       i,i
# 2           Ariana Grande                             thank u, next
# 3                  H.E.R.                                Hard Place
# 4  Jason Derulo, 2 Chainz                                Talk Dirty
#
#                     track_name  popularity explicit  danceability  energy  \
# 0                      bad guy        84.0    False         0.701   0.425
# 1                      Hey, Ma        58.0      NaN           NaN     NaN
# 2                      7 rings        84.0     True         0.778   0.317
# 3                   Hard Place        54.0      NaN           NaN     NaN
# 4  Talk Dirty (feat. 2 Chainz)        67.0      NaN           NaN     NaN
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0  7.0   -10.965   1.0        0.375         0.328              0.13    0.1000
# 1  NaN       NaN   NaN          NaN           NaN               NaN       NaN
# 2  1.0   -10.732   0.0        0.334         0.592              0.00    0.0881
# 3  NaN       NaN   NaN          NaN           NaN               NaN       NaN
# 4  NaN       NaN   NaN          NaN           NaN               NaN       NaN
#
#    valence    tempo  time_signature track_genre  duration_sec  id  duration_ms
# 0    0.562  135.128             4.0     electro       194.087 NaN          NaN
# 1      NaN      NaN             NaN         NaN           NaN NaN     216706.0
# 2    0.327  140.048             4.0       dance       178.626 NaN          NaN
# 3      NaN      NaN             NaN         NaN           NaN NaN     271733.0
# 4      NaN      NaN             NaN         NaN           NaN NaN     177685.0

# %%
import pandas as pd

csv_path = r'D:\QuintoSemestre\ETL\Grammy_Analysis\data\Grammy_And_Spotify_Merged.csv'
final_merged_df = pd.read_csv(csv_path)

# Excluir las columnas 'Unnamed: 0' y 'track_genre' al verificar NaN
columns_to_exclude = ['Unnamed: 0', 'track_genre','danceability','energy','tempo']
filtered_df = final_merged_df.drop(columns=columns_to_exclude, errors='ignore')

#filtered_df['id'] = filtered_df['id'].astype(int)
#filtered_df['year'] = filtered_df['id'].astype(int)


# Ver el número total de filas y columnas en el DataFrame (sin excluir columnas)
total_filas, total_columnas = final_merged_df.shape
print(f"Total de filas: {total_filas}")
print(f"Total de columnas: {total_columnas}")

# Ver cuántas filas tienen NaN en alguna columna (excluyendo las columnas especificadas)
filas_con_nan = filtered_df.isna().any(axis=1).sum()
print(f"Filas con valores NaN (excluyendo 'Unnamed: 0' ,'track_genre' ,'danceability','energy'y'tempo'): {filas_con_nan}")

# Ver cuántas columnas tienen al menos un NaN (excluyendo las columnas especificadas)
columnas_con_nan = filtered_df.isna().any(axis=0).sum()
print(f"Columnas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre','danceability','energy'y'tempo'): {columnas_con_nan}")
# Out:
# Total de filas: 4758
# Total de columnas: 15
# Filas con valores NaN (excluyendo 'Unnamed: 0' ,'track_genre' ,'danceability','energy'y'tempo'): 3264
# Columnas con valores NaN (excluyendo 'Unnamed: 0' y 'track_genre','danceability','energy'y'tempo'): 15

# %%
# Mostrar las primeras 10 filas que tienen NaN
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
filtered_df.head(10)

# Optional: Save the resulting DataFrame to a CSV file
output_path = r'D:\QuintoSemestre\ETL\Grammy_Analysis\data\Grammy_And_Spotify_Merged.csv'
filtered_df.to_csv(output_path, index=False)
print(f"Merge cleaned completed and file saved as '{output_path}'.")
# Out:
# Merge cleaned completed and file saved as 'D:\QuintoSemestre\ETL\Grammy_Analysis\data\Grammy_And_Spotify_Merged.csv'.
